# %%
import pandas as pd
import pyBigWig
import seaborn as sns
data='../../data/meth/wg/'

# %%
u1_f=data+'U01Met_CpG.bedGraph'
u2_f=data+'U60Met_CpG.bedGraph'

# %%
u1=pd.read_table(u1_f,skiprows=1,header=None)
print(u1.shape)
u1c22=u1[u1[0]=='chr22']
print(u1c22.shape)
u1c22[3].mean()
# Out:
# (39937846, 6)
# (938160, 6)
# 76.38895177794832

# %%
u2=pd.read_table(u2_f,skiprows=1,header=None)
print(u2.shape)
u2c22=u2[u2[0]=='chr22']
print(u2c22.shape)
u2c22[3].mean()
# Out:
# (33350619, 6)
# (824902, 6)
# 77.54039752600914

# %%
u1c22.index=u1c22[1]
u2c22.index=u2c22[1]

# %%
df=pd.concat([u1c22[3],u2c22[3]],1)
# Out:
# <ipython-input-59-92c0b712fa15>:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   df=pd.concat([u1c22[3],u2c22[3]],1)

# %%
df.columns=['1','2']
df.head()
# Out:
#            1      2
# 1
# 16050097 NaN  100.0
# 16050114 NaN  100.0
# 16050174 NaN  100.0
# 16050206 NaN  100.0
# 16050213 NaN  100.0

# %%
sns.scatterplot(data=df.head(1000000),x='1',y='2',marker='.')
# Out:
# <AxesSubplot:xlabel='1', ylabel='2'>

# %%
df.corr()
# Out:
#              1         2  size
# 1     1.000000  0.777213   NaN
# 2     0.777213  1.000000   NaN
# size       NaN       NaN   NaN

# %%
u1
# Out:
#               0         1         2    3  4  5
# 0         chr10     60514     60515  100  4  0
# 1         chr10     61333     61334   50  3  3
# 2         chr10     61652     61653   60  3  2
# 3         chr10     62730     62731  100  3  0
# 4         chr10     63584     63585    0  0  3
# ...         ...       ...       ...  ... .. ..
# 39937841   chrY  59355258  59355259  100  1  0
# 39937842   chrY  59355284  59355285  100  1  0
# 39937843   chrY  59355330  59355331  100  1  0
# 39937844   chrY  59355358  59355359  100  1  0
# 39937845   chrY  59355364  59355365    0  0  1
#
# [39937846 rows x 6 columns]
